# %% [markdown]
# # Exchange rate dataset analysis
#
# This notebook analyzes the **Exchange Rate dataset**, exploring its structure, performing preprocessing, and visualizing the time series data.
#
#
# ## **1. Library imports**

# %%
import sys
import os
sys.path.append(os.path.abspath('../../'))

# %%
from data.utils import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **2. Dataset overview**
#
# ### **Loading the dataset**

# %%
# Dataset names : exchange_rate.csv , electricity.csv , ETTm2.csv , national_illness.csv , traffic.csv , weather.csv
df = pd.read_csv("../../data/all_six_dataset/exchange_rate/exchange_rate.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7588 entries, 0 to 7587
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7588 non-null   object
#  1   0       7588 non-null   float64
#  2   1       7588 non-null   float64
#  3   2       7588 non-null   float64
#  4   3       7588 non-null   float64
#  5   4       7588 non-null   float64
#  6   5       7588 non-null   float64
#  7   6       7588 non-null   float64
#  8   OT      7588 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 533.7+ KB

# %% [markdown]
# ### **Column descriptions**
#
# This dataset tracks historical exchange rates between various currencies, providing insights into economic trends and fluctuations.
#
# | **Column name** | **Description**    |
# |------------------|--------------------|
# | `date`           | Timestamp         |
# | `0`              | Exchange rate for Australia |
# | `1`              | Exchange rate for UK        |
# | `2`              | Exchange rate for Canada    |
# | `3`              | Exchange rate for Switzerland |
# | `4`              | Exchange rate for China     |
# | `5`              | Exchange rate for Japan     |
# | `6`              | Exchange rate for New Zealand |
# | `OT`             | Exchange rate for Singapore |

# %% [markdown]
# ## **3. Preprocessing the data**
#
# ### **Convert and set date as index**

# %%
df = convert_date(df)
df.set_index('date', inplace=True)
df.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', 'OT'], dtype='object')

# %% [markdown]
# **Frequency and summary:**
# - Frequency: daily
# - Time series : 8 : {'0', '1', '2', '3', '4', '5', '6', 'OT'}
# - Total observations: 60,704
# - Test observations: 12,136
# - Rolled forecast data points: 8.74 million
# - Horizon: {96, 192, 336, 720}
#
#
#
# ## **4. Visualizing the Dataset**

# %%
plot_time_series(df) # Plot all columns of the dataset
plot_time_series(df, column='0')  # Plot a specific column

# %% [markdown]
# ## **5. Splitting the Dataset**

# %%
train, valid, test = split_data(df)
plot_data_split(train, valid, test, "0")

# %% [markdown]
# ## **6. Rolling Window Visualization**

# %%
plot_rolling_window(df["0"], 10, 5, 50)
